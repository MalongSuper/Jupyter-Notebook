# %% [markdown]
# # Python Exercises 1–25
# ## 100 Python Exercises for Beginners – Part 1

# %% [markdown]
# References: https://www.notion.so/Ex-1-Python-Exercises-36a622d6055680a8a69def24fc91c8a0?source=copy_link

# %% [markdown]
# # 1. Single Line Input: Name, Age, Major
#
# Write a program that prompts the user to enter their **name**, **age**, and **major** in a single line input. Display all values clearly.

# %%
name, age, major = input("Enter your name, age, and major separated by spaces: ").split(", ")
print(f"Name: {name}")
print(f"Age: {age}")
print(f"Major: {major}")
# Out:
# Enter your name, age, and major separated by spaces: Alice, 23, IT
# Name: Alice
# Age: 23
# Major: IT

# %% [markdown]
# # 2. US Census Bureau Population Projection
#
# Write a program that asks the user to enter a population amount and estimate future population growth.

# %%
population = int(input("Enter the current population: "))
growth_rate = float(input("Enter the population growth rate (as a decimal): "))
years = int(input("Enter the number of years to project: "))

for year in range(1, years + 1):
    population = int(population * (1 + growth_rate))
    print(f"Year {year}: Population = {population}")
# Out:
# Enter the current population: 331000
# Enter the population growth rate (as a decimal): 0.5
# Enter the number of years to project: 12
# Year 1: Population = 496500
# Year 2: Population = 744750
# Year 3: Population = 1117125
# Year 4: Population = 1675687
# Year 5: Population = 2513530
# Year 6: Population = 3770295
# Year 7: Population = 5655442
# Year 8: Population = 8483163
# Year 9: Population = 12724744
# Year 10: Population = 19087116
# Year 11: Population = 28630674
# Year 12: Population = 42946011

# %% [markdown]
# # 3. Euclidean Distance in 2D
#
# Write a program that calculates the Euclidean distance between two points in a 2D plane.
#
# ### Formula
# $$
# d = \sqrt{(x_2-x_1)^2 + (y_2-y_1)^2}
# $$

# %%
x1, y1 = map(int, input("Enter the coordinates of the first point (x1, y1): ").split(", "))
x2, y2 = map(int, input("Enter the coordinates of the second point (x2, y2): ").split(", "))
distance = ((x2 - x1) ** 2 + (y2 - y1) ** 2) ** 0.5
print(f"The distance between the two points is {distance:.2f}")
# Out:
# Enter the coordinates of the first point (x1, y1): 12, 14
# Enter the coordinates of the second point (x2, y2): 13, 18
# The distance between the two points is 4.12

# %% [markdown]
# # 4. Arithmetic Operators and Mean
#
# Define a function that takes three floating-point numbers `w`, `x`, and `y`, then computes:
# - Addition
# - Subtraction
# - Multiplication
# - Division
# - Mean

# %%
def compute(w, x, y):
    print(f"Addition: {w + x + y}")
    print(f"Subtraction: {w - x - y}")
    print(f"Multiplication: {w * x * y}")
    print(f"Division: {w / x / y}")
    print(f"Mean: {(w + x + y) / 3}")

w, x, y = map(float, input("Enter three floating-point numbers separated by spaces: ").split(", "))
compute(w, x, y)
# Out:
# Enter three floating-point numbers separated by spaces: 12, 24, 35
# Addition: 71.0
# Subtraction: -47.0
# Multiplication: 10080.0
# Division: 0.014285714285714285
# Mean: 23.666666666666668

# %% [markdown]
# # 5. Pounds and Kilograms Conversion
#
# Write a program that converts pounds to kilograms or kilograms to pounds.

# %%
pounds = float(input("Enter the weight in pounds: "))
kilograms = pounds * 0.453592
print(f"{pounds} pounds is equal to {kilograms:.2f} kilograms")
# Out:
# Enter the weight in pounds: 283
# 283.0 pounds is equal to 128.37 kilograms

# %%
kilograms = float(input("Enter the weight in kilograms: "))
pounds = kilograms / 0.453592
print(f"{kilograms} kilograms is equal to {pounds:.2f} pounds")
# Out:
# Enter the weight in kilograms: 82
# 82.0 kilograms is equal to 180.78 pounds

# %% [markdown]
# # 6. Compute MPG
#
# ### Formula
# $$
# MPG = \frac{Miles\ Driven}{Gallons\ Used}
# $$

# %%
miles_driven = float(input("Enter the number of miles driven: "))
gallons_used = float(input("Enter the number of gallons used: "))
mpg = miles_driven / gallons_used
print(f"The MPG is {mpg:.2f}")
# Out:
# Enter the number of miles driven: 23
# Enter the number of gallons used: 45.2
# The MPG is 0.51

# %% [markdown]
# # 7. Compute BMI
#
# ### Formula
# $$
# BMI = \frac{Weight(kg)}{Height(m)^2}
# $$

# %%
weight = float(input("Enter your weight in kilograms: "))
height = float(input("Enter your height in centimeters: "))
bmi = weight / (height / 100) ** 2
print(f"Your BMI is {bmi:.2f}")
# Out:
# Enter your weight in kilograms: 78
# Enter your height in centimeters: 180
# Your BMI is 24.07

# %% [markdown]
# # 8. Tip, Tax, and Total
#
# Write a program that calculates tip, tax, and final total bill.

# %%
food_cost = float(input("Enter the cost of the food: "))
tip_percent = float(input("Enter the tip percentage: "))
tax_percent = float(input("Enter the tax percentage: "))
tip = food_cost * (tip_percent / 100)
tax = food_cost * (tax_percent / 100)
total = food_cost + tip + tax
print(f"Tip: ${tip:.2f}")
print(f"Tax: ${tax:.2f}")
print(f"Total: ${total:.2f}")
# Out:
# Enter the cost of the food: 50
# Enter the tip percentage: 18
# Enter the tax percentage: 7
# Tip: $9.00
# Tax: $3.50
# Total: $62.50

# %% [markdown]
# # 9. Male and Female Percentages
#
# Write a program that displays the percentage of males and females in a class.

# %%
male = int(input("Enter the number of males in the class: "))
female = int(input("Enter the number of females in the class: "))
total = male + female
print(f"Percentage of males: {male / total * 100:.2f}%")
print(f"Percentage of females: {female / total * 100:.2f}%")
# Out:
# Enter the number of males in the class: 42
# Enter the number of females in the class: 54
# Percentage of males: 43.75%
# Percentage of females: 56.25%

# %% [markdown]
# # 10. Rectangle Perimeter and Area
#
# ### Formulas
# $$
# Perimeter = 2(l+w)
# $$
#
# $$
# Area = l \times w
# $$

# %%
height, width = map(int, input("Enter the height and width of the rectangle separated by spaces: ").split(", "))
perimeter = 2 * (height + width)
area = height * width
print(f"Perimeter: {perimeter}")
print(f"Area: {area}")
# Out:
# Enter the height and width of the rectangle separated by spaces: 12, 6
# Perimeter: 36
# Area: 72

# %% [markdown]
# # 11. Circle Circumference and Area
#
# ### Formulas
# $$
# Circumference = 2\pi r
# $$
#
# $$
# Area = \pi r^2
# $$

# %% [markdown]
# # 12. Triangle Perimeter and Area
#
# ### Formulas
# $$
# Perimeter = a+b+c
# $$
#
# $$
# s = \frac{a+b+c}{2}
# $$
#
# $$
# Area = \sqrt{s(s-a)(s-b)(s-c)}
# $$

# %%
a, b, c = map(float, input("Enter three sides of the triangle: ").split(", "))
perimeter = a + b + c
s = perimeter / 2
area = (s * (s - a) * (s - b) * (s - c)) ** 0.5
print(f"Perimeter: {perimeter}")
print(f"Area: {area}")
# Out:
# Enter three sides of the triangle: 15, 16, 19
# Perimeter: 50.0
# Area: 116.1895003862225

# %% [markdown]
# # 13. Planting Grapevines
#
# Calculate the number of grapevines that fit in a row.
#
# ### Formula
# $$
# V = \frac{R-2E}{S}
# $$
#
# Where:
# - R = Row length
# - E = End-post space
# - S = Space between vines

# %%
row_length = float(input("Enter the length of the row in feet: "))
end_post_space = float(input("Enter the amount of space used by an end-post assembly in feet: "))
space_between_vines = float(input("Enter the amount of space between the vines in feet: "))
vines = (row_length - 2 * end_post_space) / space_between_vines
print(f"- The number of grapevines that will fit in the row is {vines:.0f}")

current_vines = int(input("Enter current grapevines owned: "))
if current_vines > vines:
    print(f"+ Not enough space for {current_vines - vines} more grapevines")
else:
    print(f"+ Enough space for {vines - current_vines} more grapevines")
    # Compute minimum vineyard area required
    vineyard_area = vines * (space_between_vines + 2 * end_post_space)
    print(f"+ Minimum vineyard area required: {vineyard_area:.2f} square feet")
# Out:
# Enter the length of the row in feet: 100
# Enter the amount of space used by an end-post assembly in feet: 10
# Enter the amount of space between the vines in feet: 5
# - The number of grapevines that will fit in the row is 16
# Enter current grapevines owned: 13
# + Enough space for 3.0 more grapevines
# + Minimum vineyard area required: 400.00 square feet

# %% [markdown]
# # 14. Compound Interest
#
# ### Formula
# $$
# A = P\left(1+\frac{r}{n}\right)^{nt}
# $$

# %%
P = float(input("Enter the principal amount: "))
r = float(input("Enter the annual interest rate: ")) / 100
n = int(input("Enter the number of times interest is compounded per year: "))
t = int(input("Enter the number of years: "))

A = P * (1 + (r / n)) ** (n * t)
print(f"The final amount is {A:.2f}")
# Out:
# Enter the principal amount: 1000
# Enter the annual interest rate: 5
# Enter the number of times interest is compounded per year: 12
# Enter the number of years: 10
# The final amount is 1647.01

# %% [markdown]
# # 15. Odd and Even
#
# Write a program that determines whether a number is odd or even.

# %%
number = int(input("Enter a number: "))
if number % 2 == 0:
    print(f"{number} is even")
else:
    print(f"{number} is odd")
# Out:
# Enter a number: 13
# 13 is odd

# %% [markdown]
# # 16. Repeated Number Entry Until 0
#
# Write a program that continuously accepts numbers until the user enters `0`.

# %%
sum_numbers = 0
counts = 0
while True:
    number = int(input("Enter a number: "))
    if number == 0:
        break
    sum_numbers += number
    counts += 1
print(f"The sum of the numbers is {sum_numbers}")
print(f"The average of the numbers is {sum_numbers / counts}")
# Out:
# Enter a number: 5
# Enter a number: 10
# Enter a number: 15
# Enter a number: 20
# Enter a number: 25
# Enter a number: 30
# Enter a number: 0
# The sum of the numbers is 105
# The average of the numbers is 17.5

# %% [markdown]
# # 17. Prime Number Checker
#
# Write a program that checks whether a number is prime.

# %%
is_prime = True
number = int(input("Enter a number: "))
for i in range(2, number):
    if number % i == 0:
        is_prime = False
        print(f"{number} is not a prime number")
        break
if is_prime:
    print(f"{number} is a prime number")
# Out:
# Enter a number: 11
# 11 is a prime number

# %% [markdown]
# # 18. Palindrome Number Checker
#
# Write a program that checks whether a number is a palindrome.

# %%
def is_palindrome(number):
    return str(number) == str(number)[::-1]

number = int(input("Enter a number: "))
if is_palindrome(number):
    print(f"{number} is a palindrome")
# Out:
# Enter a number: 373
# 373 is a palindrome

# %% [markdown]
# # 19. Fibonacci Sequence Checker
#
# Write a program that checks whether a number belongs to the Fibonacci sequence.

# %%
# Retrieve all the numbers in the fibonacci sequence as a list using recursion
def get_fibonacci(n):
  sequence = []

  for i in range(0, 10 ** 3):
      sequence.append(0)
      if i == 0:
          sequence[i] = 0
      elif i == 1:
          sequence[i] = 1
      else:
          sequence[i] = sequence[i - 1] + sequence[i - 2]

  if n in sequence:
    print(f"{n} belongs to the Fibonacci sequence")
  else:
    print(f"{n} does not belong to the Fibonacci sequence")

n = int(input("Enter a number: "))
get_fibonacci(n)
# Out:
# Enter a number: 5
# 5 belongs to the Fibonacci sequence

# %% [markdown]
# # 20. Leap Year
#
# Write a program that determines whether a year is a leap year.

# %%
year = int(input("Enter a year: "))

if ((year % 4 == 0) and (year % 100 != 0)) or (year % 400 == 0):
    print(year, "is a leap year")
else:
    print(year, "is not a leap year")
# Out:
# Enter a year: 2024
# 2024 is a leap year

# %% [markdown]
# # 21. Grade Calculator
#
# Calculate the average grade across three semesters and display the final grade category.

# %%
def grade(sem1, sem2, sem3):

  if any(grade > 100 or grade < 0 for grade in [sem1, sem2, sem3]):
    return "Invalid Input"

  mean = (sem1 + sem2 + sem3) / 3

  if any(grade < 25 for grade in [sem1, sem2, sem3]):
    print("Grade = Fail")
  elif mean >= 95:
    print("Grade = Excellent")
  elif mean >= 80:
    print("Grade = Great")
  elif mean >= 65:
    print("Grade = Good")
  elif mean >= 50:
    print("Grade = Pass")

  else:
    print("Grade = Fail")

  return f"{mean:.2f}"

sem1 = float(input("Enter semester 1 grade: "))
sem2 = float(input("Enter semester 2 grade: "))
sem3 = float(input("Enter semester 3 grade: "))
print("Mean:", grade(sem1, sem2, sem3))
# Out:
# Enter semester 1 grade: 80
# Enter semester 2 grade: 80
# Enter semester 3 grade: 79.32
# Grade = Good
# Mean: 79.77

# %% [markdown]
# # 22. Hot Dog Cookout Calculator
#
# Calculate:
# - Minimum hot dog packages
# - Minimum bun packages
# - Leftovers
# - Budget analysis for condiments

# %%
import math

number_of_people = int(input("Enter number of people: "))
hot_dogs_per_person = int(input("Enter hot dogs per person: "))
number_of_hot_dogs_per_package = 8
number_of_buns_per_package = 4

# Compute
total_hot_dogs_needed = number_of_people * hot_dogs_per_person
print(f"+ Total hot dogs needed: {total_hot_dogs_needed}")

min_hot_dog_packages = math.ceil(total_hot_dogs_needed / number_of_hot_dogs_per_package)
min_bun_packages = math.ceil(total_hot_dogs_needed / number_of_buns_per_package)

leftover_hot_dogs = (min_hot_dog_packages * number_of_hot_dogs_per_package) - total_hot_dogs_needed
leftover_buns = (min_bun_packages * number_of_buns_per_package) - total_hot_dogs_needed

print(f"+ Minimum hot dog packages: {min_hot_dog_packages}")
print(f"+ Minimum bun packages: {min_bun_packages}")
print(f"+ Leftover hot dogs: {leftover_hot_dogs}")
print(f"+ Leftover buns: {leftover_buns}")


# Budget analysis for condiments
hot_dogs_cost = 6
budget = float(input("\nEnter company budget: "))
condiments_cost = 4.2

# Multiply total packages bought by package price to get total cost
total_cost = total_hot_dogs_needed * hot_dogs_cost
print(f"+ Total Cost: {total_cost}")
left_budget = budget - total_cost
print(f"+ Remaining: {left_budget}")

if total_cost >= budget:
  print("=> Could not afford condiments.")
else:
  print(f"=> Could buy at least {int(left_budget / condiments_cost)} more condiments")
# Out:
# Enter number of people: 20
# Enter hot dogs per person: 2
# + Total hot dogs needed: 40
# + Minimum hot dog packages: 5
# + Minimum bun packages: 10
# + Leftover hot dogs: 0
# + Leftover buns: 0
#
# Enter company budget: 260
# + Total Cost: 240
# + Remaining: 20.0
# => Could buy at least 4 more condiments

# %% [markdown]
# # 23. Roulette Wheel Colors Game
#
# Simulate a roulette game for two players.
#
# ### Winning Conditions
# - Exactly 3 green pockets
# - Special red/black dominance rules

# %%
import random

roulette_rules = {"Green": [0], "Red": [], "Black": []}

for i in range(1, 37):
    # Pockets 1–10
    if 1 <= i <= 10:
        if i % 2 == 1:
            roulette_rules["Red"].append(i)
        else:
            roulette_rules["Black"].append(i)
    # Pockets 11–18
    elif 11 <= i <= 18:
        if i % 2 == 1:
            roulette_rules["Black"].append(i)
        else:
            roulette_rules["Red"].append(i)
    # Pockets 19–28
    elif 19 <= i <= 28:
        if i % 2 == 1:
            roulette_rules["Red"].append(i)
        else:
            roulette_rules["Black"].append(i)
    # Pockets 29–36
    elif 29 <= i <= 36:
        if i % 2 == 1:
            roulette_rules["Black"].append(i)
        else:
            roulette_rules["Red"].append(i)

print("Green Pockets:", roulette_rules["Green"])
print("Red Pockets:", roulette_rules["Red"])
print("Black Pockets:", roulette_rules["Black"])
# Out:
# Green Pockets: [0]
# Red Pockets: [1, 3, 5, 7, 9, 12, 14, 16, 18, 19, 21, 23, 25, 27, 30, 32, 34, 36]
# Black Pockets: [2, 4, 6, 8, 10, 11, 13, 15, 17, 20, 22, 24, 26, 28, 29, 31, 33, 35]

# %%
# Randomize a sequence with 7 numbers from 0 to 36
def random_sequence():
    return random.sample(range(0, 37), 7)

def get_color(number):
    if number in roulette_rules["Green"]:
        return "Green"
    elif number in roulette_rules["Red"]:
        return "Red"
    elif number in roulette_rules["Black"]:
        return "Black"

sequence1 = random_sequence()
sequence2 = random_sequence()
sequence1_color = [get_color(number) for number in sequence1]
sequence2_color = [get_color(number) for number in sequence2]

print("Player 1 Sequence:", sequence1)
print("=> Player 1 Sequence Color:", sequence1_color)

print("\nPlayer 2 Sequence:", sequence2)
print("=> Player 1 Sequence Color:", sequence2_color)
# Out:
# Player 1 Sequence: [3, 6, 7, 26, 15, 32]
# => Player 1 Sequence Color: ['Red', 'Black', 'Red', 'Black', 'Black', 'Red']
#
# Player 2 Sequence: [17, 15, 22, 8, 4, 12]
# => Player 1 Sequence Color: ['Black', 'Black', 'Black', 'Black', 'Black', 'Red']

# %%
# Count the number of red, black, and green
def count_color(sequence):
    red = 0
    black = 0
    green = 0
    for number in sequence:
        if number in roulette_rules["Red"]:
            red += 1
        elif number in roulette_rules["Black"]:
            black += 1
        elif number in roulette_rules["Green"]:
            green += 1
    return red, black, green

sequence1_red, sequence1_black, sequence1_green = count_color(sequence1)
print("Player 1 Sequence Color Count:")
print(f"- Red: {sequence1_red}")
print(f"- Black: {sequence1_black}")
print(f"- Green: {sequence1_green}")

sequence2_red, sequence2_black, sequence2_green = count_color(sequence2)
print("\nPlayer 2 Sequence Color Count:")
print(f"- Red: {sequence2_red}")
print(f"- Black: {sequence2_black}")
print(f"- Green: {sequence2_green}")
# Out:
# Player 1 Sequence Color Count:
# - Red: 3
# - Black: 3
# - Green: 0
#
# Player 2 Sequence Color Count:
# - Red: 1
# - Black: 5
# - Green: 0

# %%
def winning_game(sequence1, sequence2):
    p1_red, p1_black, p1_green = count_color(sequence1)
    p2_red, p2_black, p2_green = count_color(sequence2)

    # Winning condition 1: Three Green Pockets (highest priority)
    if p1_green == 3 and p2_green != 3:
        return "Player 1 wins (3 Green Pockets)!"
    elif p2_green == 3 and p1_green != 3:
        return "Player 2 wins (3 Green Pockets)!"
    elif p1_green == 3 and p2_green == 3:
        return "Draw (Both have 3 Green Pockets)!"
    else:
        # No winner from Green Pockets, proceed to Advantage rules

        p1_dominant_color_count = 0
        p2_dominant_color_count = 0
        p1_qualifies_for_advantage = False
        p2_qualifies_for_advantage = False

        # Determine Player 1's dominant color count and if they qualify for an advantage
        if p1_red >= 4 and p1_black >= 1:
            p1_dominant_color_count = p1_red
            p1_qualifies_for_advantage = True
        if p1_black >= 4 and p1_red >= 1:
            # If P1 also qualifies for black advantage, take the higher count
            if p1_black > p1_dominant_color_count:
                p1_dominant_color_count = p1_black
            p1_qualifies_for_advantage = True

        # Determine Player 2's dominant color count and if they qualify for an advantage
        if p2_red >= 4 and p2_black >= 1:
            p2_dominant_color_count = p2_red
            p2_qualifies_for_advantage = True
        if p2_black >= 4 and p2_red >= 1:
            # If P2 also qualifies for black advantage, take the higher count
            if p2_black > p2_dominant_color_count:
                p2_dominant_color_count = p2_black
            p2_qualifies_for_advantage = True

        # Apply advantage and tie-breaking rules
        if p1_qualifies_for_advantage and not p2_qualifies_for_advantage:
            return "Player 1 wins (Advantage)!"
        elif p2_qualifies_for_advantage and not p1_qualifies_for_advantage:
            return "Player 2 wins (Advantage)!"
        elif p1_qualifies_for_advantage and p2_qualifies_for_advantage:
            # Both satisfy their own color advantage condition, apply HIGHER dominant count rule
            if p1_dominant_color_count > p2_dominant_color_count:
                return "Player 1 wins (Higher Dominant Color Count)!"
            elif p2_dominant_color_count > p1_dominant_color_count:
                return "Player 2 wins (Higher Dominant Color Count)!"
            else: # Dominant counts are equal
                return "Draw (Equal Dominant Color Count)!"
        else:
            return "Draw or No one wins."

# %%
# Call the winning_game function
final_result = winning_game(sequence1, sequence2)
print(final_result)
# Out:
# Player 2 wins (Advantage)!

# %% [markdown]
# # 24. Money Counting Game
#
# Convert dollars into pennies, nickels, dimes, and quarters.
#
# ### Formula
# $$
# Cents = Dollars \times 100
# $$

# %%
dollars = float(input("Enter the amount of money in dollars: "))

# Compute cents, pennies, nickels, dimes, and quarters
cents = int(dollars * 100)
# Conversion
pennies = cents
nickels = cents // 5
dimes = cents // 10
quarters = cents // 25

print(f"The amount of money in cents is {cents:.2f}")
print(f"The amount of money in pennies is {pennies:.2f}")
print(f"The amount of money in nickels is {nickels}")
print(f"The amount of money in dimes is {dimes}")
# Out:
# Enter the amount of money in dollars: 2.35
# The amount of money in cents is 235.00
# The amount of money in pennies is 235.00
# The amount of money in nickels is 47
# The amount of money in dimes is 23

# %% [markdown]
# # 25. Time Conversion
#
# Convert seconds into minutes, hours, and days.
#
# ### Formulas
# $$
# Minutes = \frac{Seconds}{60}
# $$
#
# $$
# Hours = \frac{Seconds}{3600}
# $$
#
# $$
# Days = \frac{Seconds}{86400}
# $$

# %%
seconds = int(input("Enter the amount of seconds: "))

# Compute minutes, hours, and days
minutes = seconds / 60
hours = seconds / 3600
days = seconds / 86400
print(f"The amount of seconds in minutes is {minutes:.2f}")
print(f"The amount of seconds in hours is {hours:.2f}")
print(f"The amount of seconds in days is {days:.2f}")
# Out:
# Enter the amount of seconds: 212000
# The amount of seconds in minutes is 3533.33
# The amount of seconds in hours is 58.89
# The amount of seconds in days is 2.45

# %%
days = int(input("Enter the number of days: "))
# Convert to month
print(f"Month: {days / 31:.2f}")
# Convert to year
print(f"Year: {days / 365:.2f}")
# Out:
# Enter the number of days: 366
# Month: 11.81
# Year: 1.00

# %%
# Convert days, hours, minutes, seconds -> seconds
days = int(input("Enter the number of days: "))
hours = int(input("Enter the number of hours: "))
minutes = int(input("Enter the number of minutes: "))
seconds = int(input("Enter the number of seconds: "))

total_seconds = (days * 86400) + (hours * 3600) + (minutes * 60) + seconds
print(f"Total seconds: {total_seconds}")
# Out:
# Enter the number of days: 2
# Enter the number of hours: 3
# Enter the number of minutes: 34
# Enter the number of seconds: 12
# Total seconds: 185652
